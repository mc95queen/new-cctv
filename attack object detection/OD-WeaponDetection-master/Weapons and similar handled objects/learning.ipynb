# %%
from ultralytics import YOLO
import torch

device = torch.device('mps:0' if torch.backends.mps.is_available() else 'cpu')

model = YOLO("yolov8n.pt", device = "mps")

model.train(data = r"/Users/jiho/Desktop/personal/school/IJSHS/2023/''' 2023 입시/특기 입증자료/OpenCV를 이용한 CCTV 분석 스마트 보안 시스템/attack object detection/OD-WeaponDetection-master/Weapons and similar handled objects/dataset.yaml1",epochs=100,imgsz = 640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.168 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.157 🚀 Python-3.11.4 torch-2.0.1 CPU (Apple M2 Pro)
# ...
